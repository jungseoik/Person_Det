# %%
from eval.set_label import setting_extract_label

setting_extract_label()
# Out:
# Error processing /mnt/nas_192tb/videos/AI_Hub_실내외_밀집군중_데이터_이미지/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_1.CCTV_1.EXCO_100.Indoor_EXCO100(62)_json/Indoor_EXCO100_010.json: Unexpected UTF-8 BOM (decode using utf-8-sig): line 1 column 1 (char 0)
# Error processing /mnt/nas_192tb/videos/AI_Hub_실내외_밀집군중_데이터_이미지/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_1.CCTV_1.EXCO_100.Indoor_EXCO100(62)_json/Indoor_EXCO100_171.json: Unexpected UTF-8 BOM (decode using utf-8-sig): line 1 column 1 (char 0)
# Error processing /mnt/nas_192tb/videos/AI_Hub_실내외_밀집군중_데이터_이미지/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_1.CCTV_1.EXCO_100.Indoor_EXCO100(62)_json/Indoor_EXCO100_123.json: Unexpected UTF-8 BOM (decode using utf-8-sig): line 1 column 1 (char 0)
# Error processing /mnt/nas_192tb/videos/AI_Hub_실내외_밀집군중_데이터_이미지/01-1.정식개방데이터/Validation/02.라벨링데이터/VL_1.CCTV_1.EXCO_100.Indoor_EXCO100(62)_json/Indoor_EXCO100_333.json: Unexpected UTF-8 BOM (decode using utf-8-sig): line 1 column 1 (char 0)
# ...
